# %%
import func2
func2.compare("YS")
# Out:
# 最大尤度:  1.1699854737199902e-182
# 最大尤度を取るインデックス:  (19, 28)
# 最大尤度を取るインデックス:  (33, 50)
# 100
# 100
# 100
# 実行時間:5.698655843734741[sec]
# 最大尤度:  1.590626573900829e-128
# 最大尤度を取るインデックス:  (19, 26)
# 最大尤度を取るインデックス:  (32, 49)
# 100
# 100
# 100
# 実行時間:4.480759143829346[sec]
# 最大尤度:  1.243700991391357e-120
# 最大尤度を取るインデックス:  (20, 25)
# 最大尤度を取るインデックス:  (12, 55)
# 100
# 100
# 100
# 実行時間:4.251582860946655[sec]
# 最大尤度:  9.137917235087953e-124
# 最大尤度を取るインデックス:  (20, 25)
# 最大尤度を取るインデックス:  (24, 53)
# 100
# 100
# 100
# 実行時間:4.456141710281372[sec]
# 最大尤度:  1.3233222840082328e-134
# 最大尤度を取るインデックス:  (19, 28)
# 最大尤度を取るインデックス:  (24, 56)
# 100
# 100
# 100
# 実行時間:4.357253074645996[sec]
