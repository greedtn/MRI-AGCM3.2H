# %%
import func2
func2.compare("AS")
# Out:
# 最大尤度:  7.733767928830524e-118
# 最大尤度を取るインデックス:  (20, 26)
# 最大尤度を取るインデックス:  (30, 59)
# 100
# 100
# 100
# 実行時間:4.099573135375977[sec]
# 最大尤度:  2.380519160037717e-63
# 最大尤度を取るインデックス:  (19, 28)
# 最大尤度を取るインデックス:  (33, 52)
# 100
# 100
# 100
# 実行時間:2.370471954345703[sec]
# 最大尤度:  4.418253819974015e-83
# 最大尤度を取るインデックス:  (19, 26)
# 最大尤度を取るインデックス:  (24, 52)
# 100
# 100
# 100
# 実行時間:3.243683099746704[sec]
# 最大尤度:  1.0960122846800563e-73
# 最大尤度を取るインデックス:  (19, 26)
# 最大尤度を取るインデックス:  (17, 60)
# 100
# 100
# 100
# 実行時間:2.9565141201019287[sec]
# 最大尤度:  2.3859643856497026e-79
# 最大尤度を取るインデックス:  (19, 27)
# 最大尤度を取るインデックス:  (7, 59)
# 100
# 100
# 100
# 実行時間:3.0426461696624756[sec]
