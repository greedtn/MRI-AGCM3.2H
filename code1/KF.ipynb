# %%
import func2
func2.compare("KF")
# Out:
# 最大尤度:  2.4024926630746292e-180
# 最大尤度を取るインデックス:  (20, 26)
# 最大尤度を取るインデックス:  (21, 58)
# 100
# 100
# 100
# 実行時間:5.9043190479278564[sec]
# 最大尤度:  7.991630962429963e-146
# 最大尤度を取るインデックス:  (20, 28)
# 最大尤度を取るインデックス:  (28, 52)
# 100
# 100
# 100
# 実行時間:4.532204866409302[sec]
# 最大尤度:  3.356587672116712e-141
# 最大尤度を取るインデックス:  (19, 26)
# 最大尤度を取るインデックス:  (35, 52)
# 100
# 100
# 100
# 実行時間:4.836555004119873[sec]
# 最大尤度:  2.732836636680175e-143
# 最大尤度を取るインデックス:  (20, 26)
# 最大尤度を取るインデックス:  (19, 58)
# 100
# 100
# 100
# 実行時間:4.62879490852356[sec]
# 最大尤度:  2.2855780841081885e-184
# 最大尤度を取るインデックス:  (19, 28)
# 最大尤度を取るインデックス:  (10, 65)
# 100
# 100
# 100
# 実行時間:5.627179861068726[sec]
