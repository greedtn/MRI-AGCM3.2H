# %%
import func
POT, POT_IDX, CNT, POT_LEN = func.calc_pot(thr=9.0, dir_path="/Volumes/HDCL-UT/MRI-AGCM3.2H_WW3_wave/HFA_YS_c2/", param_name="103", output_csv="../csv/HFA_YS_c2.csv")
# Out:
# Jpn_30min.2075010100.grib...now
# Jpn_30min.2075020100.grib...now
# Jpn_30min.2075030100.grib...now
# Jpn_30min.2075040100.grib...now
# Jpn_30min.2075050100.grib...now
# Jpn_30min.2075060100.grib...now
# Jpn_30min.2075070100.grib...now
# Jpn_30min.2075080100.grib...now
# Jpn_30min.2075090100.grib...now
# Jpn_30min.2075100100.grib...now
# Jpn_30min.2075110100.grib...now
# Jpn_30min.2075120100.grib...now
# Jpn_30min.2076010100.grib...now
# Jpn_30min.2076020100.grib...now
# Jpn_30min.2076030100.grib...now
# Jpn_30min.2076040100.grib...now
# Jpn_30min.2076050100.grib...now
# Jpn_30min.2076060100.grib...now
# Jpn_30min.2076070100.grib...now
# Jpn_30min.2076080100.grib...now
# Jpn_30min.2076090100.grib...now
# Jpn_30min.2076100100.grib...now
# Jpn_30min.2076110100.grib...now
# Jpn_30min.2076120100.grib...now
# Jpn_30min.2077010100.grib...now
# Jpn_30min.2077020100.grib...now
# Jpn_30min.2077030100.grib...now
# Jpn_30min.2077040100.grib...now
# Jpn_30min.2077050100.grib...now
# ...
