# %%
import func
func.calc_RV_p("YS")
# Out:
# 現在 0 / 6240 now
# 現在 1 / 6240 now
# 現在 2 / 6240 now
# 現在 3 / 6240 now
# 現在 4 / 6240 now
# 現在 5 / 6240 now
# 現在 6 / 6240 now
# 現在 7 / 6240 now
# 現在 8 / 6240 now
# 現在 9 / 6240 now
# 現在 10 / 6240 now
# 現在 11 / 6240 now
# 現在 12 / 6240 now
# 現在 13 / 6240 now
# 現在 14 / 6240 now
# 現在 15 / 6240 now
# 現在 16 / 6240 now
# 現在 17 / 6240 now
# 現在 18 / 6240 now
# 現在 19 / 6240 now
# 現在 20 / 6240 now
# 現在 21 / 6240 now
# 現在 22 / 6240 now
# 現在 23 / 6240 now
# 現在 24 / 6240 now
# 現在 25 / 6240 now
# 現在 26 / 6240 now
# 現在 27 / 6240 now
# 現在 28 / 6240 now
# 現在 29 / 6240 now
# 現在 30 / 6240 now
# 現在 31 / 6240 now
# 現在 32 / 6240 now
# 現在 33 / 6240 now
# 現在 34 / 6240 now
# 現在 35 / 6240 now
# 現在 36 / 6240 now
# 現在 37 / 6240 now
# 現在 38 / 6240 now
# 現在 39 / 6240 now
# 現在 40 / 6240 now
# 現在 41 / 6240 now
# 現在 42 / 6240 now
# 現在 43 / 6240 now
# 現在 44 / 6240 now
# 現在 45 / 6240 now
# 現在 46 / 6240 now
# 現在 47 / 6240 now
# 現在 48 / 6240 now
# 現在 49 / 6240 now
# 現在 50 / 6240 now
# 現在 51 / 6240 now
# 現在 52 / 6240 now
# ...
