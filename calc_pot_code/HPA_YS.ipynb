# %%
import func
func.calc_pot_all(thr=9.0, dir_path="/Volumes/HDCL-UT/MRI-AGCM3.2H_WW3_wave/HPA_AS/", param_name="103", model_name='HPA_YS')
# Out:
# ----- 1 / 744 done (64秒で実行) -----
# ----- 2 / 744 done (57秒で実行) -----
# ----- 3 / 744 done (41秒で実行) -----
# ----- 4 / 744 done (59秒で実行) -----
# ----- 5 / 744 done (68秒で実行) -----
# ----- 6 / 744 done (69秒で実行) -----
# ----- 7 / 744 done (58秒で実行) -----
# ----- 8 / 744 done (33秒で実行) -----
# ----- 9 / 744 done (63秒で実行) -----
# ----- 10 / 744 done (72秒で実行) -----
# ----- 11 / 744 done (70秒で実行) -----
# ----- 12 / 744 done (67秒で実行) -----
# ----- 13 / 744 done (45秒で実行) -----
# ----- 14 / 744 done (42秒で実行) -----
# ----- 15 / 744 done (70秒で実行) -----
# ----- 16 / 744 done (68秒で実行) -----
# ----- 17 / 744 done (69秒で実行) -----
# ----- 18 / 744 done (66秒で実行) -----
# ----- 19 / 744 done (37秒で実行) -----
# ----- 20 / 744 done (51秒で実行) -----
# ----- 21 / 744 done (68秒で実行) -----
# ----- 22 / 744 done (73秒で実行) -----
# ----- 23 / 744 done (73秒で実行) -----
# ----- 24 / 744 done (76秒で実行) -----
# ----- 25 / 744 done (73秒で実行) -----
# ----- 26 / 744 done (70秒で実行) -----
# ----- 27 / 744 done (73秒で実行) -----
# ...
