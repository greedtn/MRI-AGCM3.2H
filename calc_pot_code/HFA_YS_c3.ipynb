# %%
import func
func.calc_pot_all(thr=9.0, dir_path="/Volumes/HDCL-UT/MRI-AGCM3.2H_WW3_wave/HFA_YS_c3/", param_name="103", output_pot="../csv2/HFA_YS_c3_POT.csv", output_pot_idx="../csv2/HFA_YS_c3_POT_IDX.csv", output_cnt="../csv2/HFA_YS_c3_CNT.csv")
# Out:
# ----- 1 / 600 done (44秒で実行) -----
# ----- 2 / 600 done (44秒で実行) -----
# ----- 3 / 600 done (70秒で実行) -----
# ----- 4 / 600 done (67秒で実行) -----
# ----- 5 / 600 done (66秒で実行) -----
# ----- 6 / 600 done (46秒で実行) -----
# ----- 7 / 600 done (50秒で実行) -----
# ----- 8 / 600 done (68秒で実行) -----
# ----- 9 / 600 done (70秒で実行) -----
# ----- 10 / 600 done (73秒で実行) -----
# ----- 11 / 600 done (69秒で実行) -----
# ----- 12 / 600 done (56秒で実行) -----
# ----- 13 / 600 done (34秒で実行) -----
# ----- 14 / 600 done (62秒で実行) -----
# ----- 15 / 600 done (71秒で実行) -----
# ----- 16 / 600 done (68秒で実行) -----
# ----- 17 / 600 done (63秒で実行) -----
# ----- 18 / 600 done (40秒で実行) -----
# ----- 19 / 600 done (52秒で実行) -----
# ----- 20 / 600 done (69秒で実行) -----
# ----- 21 / 600 done (70秒で実行) -----
# ----- 22 / 600 done (72秒で実行) -----
# ----- 23 / 600 done (71秒で実行) -----
# ----- 24 / 600 done (63秒で実行) -----
# ----- 25 / 600 done (31秒で実行) -----
# ----- 26 / 600 done (60秒で実行) -----
# ----- 27 / 600 done (72秒で実行) -----
# ...
