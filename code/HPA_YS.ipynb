# %%
import func
POT, POT_IDX, CNT, POT_LEN = func.calc_pot(thr=9.0, dir_path="/Volumes/HDCL-UT/MRI-AGCM3.2H_WW3_wave/HPA_YS/", param_name="103", output_csv="../csv/HPA_YS.csv")
# Out:
# Jpn_30min.1979010100.grib...now
# Jpn_30min.1979020100.grib...now
# Jpn_30min.1979030100.grib...now
# Jpn_30min.1979040100.grib...now
# Jpn_30min.1979050100.grib...now
# Jpn_30min.1979060100.grib...now
# Jpn_30min.1979070100.grib...now
# Jpn_30min.1979080100.grib...now
# Jpn_30min.1979090100.grib...now
# Jpn_30min.1979100100.grib...now
# Jpn_30min.1979110100.grib...now
# Jpn_30min.1979120100.grib...now
# Jpn_30min.1980010100.grib...now
# Jpn_30min.1980020100.grib...now
# Jpn_30min.1980030100.grib...now
# Jpn_30min.1980040100.grib...now
# Jpn_30min.1980050100.grib...now
# Jpn_30min.1980060100.grib...now
# Jpn_30min.1980070100.grib...now
# Jpn_30min.1980080100.grib...now
# Jpn_30min.1980090100.grib...now
# Jpn_30min.1980100100.grib...now
# Jpn_30min.1980110100.grib...now
# Jpn_30min.1980120100.grib...now
# Jpn_30min.1981010100.grib...now
# Jpn_30min.1981020100.grib...now
# Jpn_30min.1981030100.grib...now
# Jpn_30min.1981040100.grib...now
# Jpn_30min.1981050100.grib...now
# ...
