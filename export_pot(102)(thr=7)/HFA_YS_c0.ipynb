# %%
import func
func.calc_pot_all(thr=7.0, dir_path='/Volumes/HDCL-UT/MRI-AGCM3.2H_WW3_wave/HFA_YS_c0/', param_name='100', model_name='HFA_YS_c0')
# Out:
# ----- 1 / 300 done
# ----- 2 / 300 done
# ----- 3 / 300 done
# ----- 4 / 300 done
# ----- 5 / 300 done
# ----- 6 / 300 done
# ----- 7 / 300 done
# ----- 8 / 300 done
# ----- 9 / 300 done
# ----- 10 / 300 done
# ----- 11 / 300 done
# ----- 12 / 300 done
# ----- 13 / 300 done
# ----- 14 / 300 done
# ----- 15 / 300 done
# ----- 16 / 300 done
# ----- 17 / 300 done
# ----- 18 / 300 done
# ----- 19 / 300 done
# ----- 20 / 300 done
# ----- 21 / 300 done
# ----- 22 / 300 done
# ----- 23 / 300 done
# ----- 24 / 300 done
# ----- 25 / 300 done
# ----- 26 / 300 done
# ----- 27 / 300 done
# ----- 28 / 300 done
# ----- 29 / 300 done
# ----- 30 / 300 done
# ----- 31 / 300 done
# ----- 32 / 300 done
# ----- 33 / 300 done
# ----- 34 / 300 done
# ----- 35 / 300 done
# ----- 36 / 300 done
# ----- 37 / 300 done
# ----- 38 / 300 done
# ----- 39 / 300 done
# ----- 40 / 300 done
# ----- 41 / 300 done
# ----- 42 / 300 done
# ----- 43 / 300 done
# ----- 44 / 300 done
# ----- 45 / 300 done
# ...
